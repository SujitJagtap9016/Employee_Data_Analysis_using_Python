# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Lenovo\Downloads\archive (1)\employee.csv")
df
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4653 entries, 0 to 4652
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Education                  4653 non-null   object
#  1   JoiningYear                4653 non-null   int64
#  2   City                       4653 non-null   object
#  3   PaymentTier                4653 non-null   int64
#  4   Age                        4653 non-null   int64
#  5   Gender                     4653 non-null   object
#  6   EverBenched                4653 non-null   object
#  7   ExperienceInCurrentDomain  4653 non-null   int64
#  8   LeaveOrNot                 4653 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 327.3+ KB

# %%
df.head()
# Out:
#    Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0  Bachelors         2017  Bangalore            3   34    Male          No
# 1  Bachelors         2013       Pune            1   28  Female          No
# 2  Bachelors         2014  New Delhi            3   38  Female          No
# 3    Masters         2016  Bangalore            3   27    Male          No
# 4    Masters         2017       Pune            3   24    Male         Yes
#
#    ExperienceInCurrentDomain  LeaveOrNot
# 0                          0           0
# 1                          3           1
# 2                          2           0
# 3                          5           1
# 4                          2           1

# %%
df.tail()
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
#       ExperienceInCurrentDomain  LeaveOrNot
# 4648                          4           0
# 4649                          2           1
# 4650                          5           1
# 4651                          2           0
# 4652                          4           0

# %%
pd.isnull(df).sum()
# Out:
# Education                    0
# JoiningYear                  0
# City                         0
# PaymentTier                  0
# Age                          0
# Gender                       0
# EverBenched                  0
# ExperienceInCurrentDomain    0
# LeaveOrNot                   0
# dtype: int64

# %%
df.shape
# Out:
# (4653, 9)

# %%
def conv(value):
    if value == 1:
        return "Yes"
    else:
        return "No"
df['LeaveOrNot'] = df["LeaveOrNot"].apply(conv)

# %%
df.head()
# Out:
#    Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0  Bachelors         2017  Bangalore            3   34    Male          No
# 1  Bachelors         2013       Pune            1   28  Female          No
# 2  Bachelors         2014  New Delhi            3   38  Female          No
# 3    Masters         2016  Bangalore            3   27    Male          No
# 4    Masters         2017       Pune            3   24    Male         Yes
#
#    ExperienceInCurrentDomain LeaveOrNot
# 0                          0         No
# 1                          3        Yes
# 2                          2         No
# 3                          5        Yes
# 4                          2        Yes

# %%
df.describe()
# Out:
#        JoiningYear  PaymentTier          Age  ExperienceInCurrentDomain
# count  4653.000000  4653.000000  4653.000000                4653.000000
# mean   2015.062970     2.698259    29.393295                   2.905652
# std       1.863377     0.561435     4.826087                   1.558240
# min    2012.000000     1.000000    22.000000                   0.000000
# 25%    2013.000000     3.000000    26.000000                   2.000000
# 50%    2015.000000     3.000000    28.000000                   3.000000
# 75%    2017.000000     3.000000    32.000000                   4.000000
# max    2018.000000     3.000000    41.000000                   7.000000

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4648     True
# 4649    False
# 4650    False
# 4651    False
# 4652     True
# Length: 4653, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 1889

# %%
df.head()
# Out:
#    Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0  Bachelors         2017  Bangalore            3   34    Male          No
# 1  Bachelors         2013       Pune            1   28  Female          No
# 2  Bachelors         2014  New Delhi            3   38  Female          No
# 3    Masters         2016  Bangalore            3   27    Male          No
# 4    Masters         2017       Pune            3   24    Male         Yes
#
#    ExperienceInCurrentDomain LeaveOrNot
# 0                          0         No
# 1                          3        Yes
# 2                          2         No
# 3                          5        Yes
# 4                          2        Yes

# %%
ax = sns.countplot(x='City', data=df)
plt.show()

# %%
ax = sns.countplot(x='City', data=df)
ax.bar_label(ax.containers[0]) 
plt.show()

# %%
plt.figure(figsize=(3,4))
ax = sns.countplot(x='City', data=df)
ax.bar_label(ax.containers[0]) 
plt.show()

# %% [markdown]
# Count of the employees belongs to the Cities.

# %%
gb = df.groupby("City").agg({'City':"count"})
plt.pie(gb['City'])
plt.show()

# %%
gb = df.groupby("City").agg({'City':"count"})
plt.pie(gb['City'],labels=gb.index, autopct="%1.2f%%")
plt.show()

# %% [markdown]
# Percentages of the employees belongs to the Cities.

# %%
df.head()
# Out:
#    Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0  Bachelors         2017  Bangalore            3   34    Male          No
# 1  Bachelors         2013       Pune            1   28  Female          No
# 2  Bachelors         2014  New Delhi            3   38  Female          No
# 3    Masters         2016  Bangalore            3   27    Male          No
# 4    Masters         2017       Pune            3   24    Male         Yes
#
#    ExperienceInCurrentDomain LeaveOrNot
# 0                          0         No
# 1                          3        Yes
# 2                          2         No
# 3                          5        Yes
# 4                          2        Yes

# %%
cities = df['City'].unique()
fig, axes = plt.subplots(1, len(cities), figsize=(15, 5)) 

for i, city in enumerate(cities):
    ax = sns.countplot(x='Gender', hue='Gender', data=df[df['City'] == city], ax=axes[i])
    ax.set_title(f'Gender Distribution in {city}')

    for container in ax.containers: 
        ax.bar_label(container) 

plt.tight_layout()
plt.show()

# %% [markdown]
# City wise Male and Female Employees

# %%
df.head()
# Out:
#    Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0  Bachelors         2017  Bangalore            3   34    Male          No
# 1  Bachelors         2013       Pune            1   28  Female          No
# 2  Bachelors         2014  New Delhi            3   38  Female          No
# 3    Masters         2016  Bangalore            3   27    Male          No
# 4    Masters         2017       Pune            3   24    Male         Yes
#
#    ExperienceInCurrentDomain LeaveOrNot
# 0                          0         No
# 1                          3        Yes
# 2                          2         No
# 3                          5        Yes
# 4                          2        Yes

# %%
plt.figure(figsize=(20,16))
ax = sns.histplot(x="Age", data=df, hue='Gender')
for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

# %% [markdown]
# Age wise total employees.
# Devided into the Male and Female.

# %%
df.head()
# Out:
#    Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0  Bachelors         2017  Bangalore            3   34    Male          No
# 1  Bachelors         2013       Pune            1   28  Female          No
# 2  Bachelors         2014  New Delhi            3   38  Female          No
# 3    Masters         2016  Bangalore            3   27    Male          No
# 4    Masters         2017       Pune            3   24    Male         Yes
#
#    ExperienceInCurrentDomain LeaveOrNot
# 0                          0         No
# 1                          3        Yes
# 2                          2         No
# 3                          5        Yes
# 4                          2        Yes

# %%
df.columns.values
# Out:
# array(['Education', 'JoiningYear', 'City', 'PaymentTier', 'Age', 'Gender',
#        'EverBenched', 'ExperienceInCurrentDomain', 'LeaveOrNot'],
#       dtype=object)

# %%
plt.figure(figsize=(10, 6))
ax = sns.countplot(x='Age', hue='LeaveOrNot', data=df)

for container in ax.containers: 
        ax.bar_label(container) 

plt.title('Employee Attrition by Age')
plt.xlabel('Age')
plt.ylabel('Number of Employees')
plt.legend(title='Left Company')

plt.show()

# %%
df.head()
# Out:
#    Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0  Bachelors         2017  Bangalore            3   34    Male          No
# 1  Bachelors         2013       Pune            1   28  Female          No
# 2  Bachelors         2014  New Delhi            3   38  Female          No
# 3    Masters         2016  Bangalore            3   27    Male          No
# 4    Masters         2017       Pune            3   24    Male         Yes
#
#    ExperienceInCurrentDomain LeaveOrNot
# 0                          0         No
# 1                          3        Yes
# 2                          2         No
# 3                          5        Yes
# 4                          2        Yes

# %%
city_gender_counts = df.groupby(['City', 'Gender']).size().unstack()
city_gender_counts.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title('Proportion of Employees by City and Gender')
plt.xlabel('City')
plt.ylabel('Number of Employees')
plt.xticks(rotation=45)
plt.legend(title='Gender')
plt.show()

# %%
plt.figure(figsize=(10, 6))
ax = sns.countplot(x='City', hue='Gender', data=df)
plt.title('Employee Distribution by City and Gender')
plt.xlabel('City')
plt.ylabel('Number of Employees')
plt.xticks(rotation=45)
plt.legend(title='Gender')

for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{height}', 
                xy=(p.get_x() + p.get_width() / 2, height), 
                ha='center', va='bottom')

plt.show()

# %%
df.head()
# Out:
#    Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0  Bachelors         2017  Bangalore            3   34    Male          No
# 1  Bachelors         2013       Pune            1   28  Female          No
# 2  Bachelors         2014  New Delhi            3   38  Female          No
# 3    Masters         2016  Bangalore            3   27    Male          No
# 4    Masters         2017       Pune            3   24    Male         Yes
#
#    ExperienceInCurrentDomain LeaveOrNot
# 0                          0         No
# 1                          3        Yes
# 2                          2         No
# 3                          5        Yes
# 4                          2        Yes

# %%
city_leave_counts = df.groupby(['City', 'LeaveOrNot']).size().unstack()
city_leave_counts = city_leave_counts.div(city_leave_counts.sum(axis=1), axis=0)

for city in city_leave_counts.index:
    plt.figure(figsize=(5, 5))
    plt.pie(city_leave_counts.loc[city], labels=city_leave_counts.columns, autopct='%1.1f%%', startangle=90)
    plt.title(f'Leave Status in {city}')
    plt.show()

# %%
df.head()
# Out:
#    Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0  Bachelors         2017  Bangalore            3   34    Male          No
# 1  Bachelors         2013       Pune            1   28  Female          No
# 2  Bachelors         2014  New Delhi            3   38  Female          No
# 3    Masters         2016  Bangalore            3   27    Male          No
# 4    Masters         2017       Pune            3   24    Male         Yes
#
#    ExperienceInCurrentDomain LeaveOrNot
# 0                          0         No
# 1                          3        Yes
# 2                          2         No
# 3                          5        Yes
# 4                          2        Yes

# %%
g = sns.FacetGrid(df, col="City", row="Gender")
g.map(sns.histplot, "Age")
plt.show()

# %%
plt.figure(figsize=(10, 5))
ax = sns.barplot(x='City', y='Age', hue='Education', data=df)
plt.title('Average Age by City and Education')
plt.xlabel('City')
plt.ylabel('Average Age')
plt.xticks(rotation=45)
plt.legend(title='Education')

for container in ax.containers:
    for bar in container:
        height = bar.get_height()
        ax.text(bar.get_x() + bar.get_width() / 2, height + 5, f'{int(height)}', 
                ha='center', va='bottom')

plt.show()

# %%
df.head()
# Out:
#    Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0  Bachelors         2017  Bangalore            3   34    Male          No
# 1  Bachelors         2013       Pune            1   28  Female          No
# 2  Bachelors         2014  New Delhi            3   38  Female          No
# 3    Masters         2016  Bangalore            3   27    Male          No
# 4    Masters         2017       Pune            3   24    Male         Yes
#
#    ExperienceInCurrentDomain LeaveOrNot
# 0                          0         No
# 1                          3        Yes
# 2                          2         No
# 3                          5        Yes
# 4                          2        Yes

# %%
df_stayed = df[df['LeaveOrNot'] == 'No']
plt.figure(figsize=(10, 6))
ax = sns.histplot(data=df_stayed, x='Age', bins=20) 
ax.bar_label(ax.containers[0]) 
plt.title('Age Distribution of Employees Who Stayed')
plt.xlabel('Age')
plt.ylabel('Number of Employees')
plt.show()

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 6))
fig.suptitle('Employee Distribution by City and Gender (by Education)')

for i, edu in enumerate(df['Education'].unique()):
    ax = sns.countplot(x='City', hue='Gender', data=df[df['Education'] == edu], ax=axes[i])
    for container in ax.containers: 
        ax.bar_label(container) 
    axes[i].set_title(f'Education: {edu}')
    axes[i].set_xlabel('City')
    axes[i].set_ylabel('Number of Employees')
    axes[i].legend(title='Gender')
    axes[i].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()
